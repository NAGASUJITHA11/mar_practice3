# %%
# wap ask the user enter a number
# print it is an even or odd
# ans)function without,with and default

def even_odd():
    num=eval(input('enter a number:'))
    if num%2==0:
        print(f'{num} is an even number')
    else:
        print(f'{num}is an odd number')
even_odd()


def even_odd1(num1):
    if num1%2==0:
        print(f'{num1} is an even number')
    else:
        print(f'{num1} is an odd number')
even_odd1(35)


def even_odd2(num2=26):
    if num2%2==0:
        print(f'{num2} is an even number')
    else:
        print(f'{num2} is an odd number')
even_odd2()
# Out:
# enter a number: 5
# 5is an odd number
# 35 is an odd number
# 26 is an even number

# %%
def even_odd():
    num=eval(input('enter a number:'))
    if num%2==0:
        print(f'{num} is an even number')
    else:
        print(f'{num}is an odd number')
even_odd()
# Out:
# enter a number: 25
# 25is an odd number

# %%
num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 num
#
# NameError: name 'num' is not defined

# %%
def even_odd2(num2=26):
    global num2
    if num2%2==0:
        print(f'{num2} is an even number')
    else:
        print(f'{num2} is an odd number')
even_odd2()
# Out:
#   Cell In[20], line 2
#     global num2
#     ^
# SyntaxError: name 'num2' is parameter and global

# %%
# swapping of numbers or interchanging of numbers
a=10
b=20
a,b=b,a
print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
# **parameters vs variables**

# %% [markdown]
# - parameters also called as arguments
#     - this always inside the function brackets
# - variables either outside the function or inside the function

# %% [markdown]
# **return**
#
# - return means function is giving something
# - we know that local variables cannot use outside the function
# - inorder to use local variables outside the function we have two methods
#     - using **global**
#     - using **return**

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)
add()
# Out:
# 30

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
def add():
    global c
    a=10
    b=20
    c=a+b
    print(c)
add()
# Out:
# 30

# %%
c
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)
    return(c)     # same as print but to take the value again
c=add()           # for save the value make c=add()
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)
    return(a,c)     # same as print but to take the value again
a,c=add()           # for save the value make c=add()
# Out:
# 30

# %%
value=10,20
value        #tuple
# Out:
# (10, 20)

# %%
val1,val2=10,20
val1
# Out:
# 10

# %%
val2
# Out:
# 20

# %%
val1,val2=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 val1,val2=10
#
# TypeError: cannot unpack non-iterable int object

# %%
def add():
    a=10
    b=20
    c=a+b
    return(c)
c=add()
print(c)
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    return(a,c)
a,c=add()
print(a,c)
# Out:
# 10 30

# %%
def add():
    a=10
    b=20
    c=a+b
    return(a,c)
a,c=add()
print(a)
print(c)
# Out:
# 10
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    print(a)
    print(c)
    return(a,c)
a,c=add()
# Out:
# 10
# 30

# %%
def avg(a,b,c):
    summ=a+b+c
    AVG=summ/3
    return(summ,AVG)
summ,AVG=avg(10,20,30)
print(summ)
print(AVG)
# Out:
# 60
# 20.0

# %%
def avg(a,b,c):
    summ=a+b+c
    AVG=summ/3
    return(summ,AVG)
avg(10,20,30)
# Out:
# (60, 20.0)

# %%
def avg(a,b,c):
    summ=a+b+c
    AVG=summ/3
    return(summ,AVG)
summ,AVG=avg(10,20,30)
print(summ)
print(AVG)
# Out:
# 60
# 20.0

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        print(f'{num2} is an even number')
    else:
        print(f'{num2} is an odd number')
    
even_odd()
# Out:
# enter a number: 45
# 45 is an odd number

# %%
def even_odd():
    nu2=eval(input('enter a number:'))
    if nu2%2==0:
        print(f'{nu2} is an even number')
    else:
        print(f'{nu2} is an odd number')
    
even_odd()
# Out:
# enter a number: 45
# 45 is an odd number

# %%
nu2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 nu2
#
# NameError: name 'nu2' is not defined

# %%
num2
# Out:
# 58

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        print(f'{num2} is an even number')
    else:
        print(f'{num2} is an odd number')
    return(num2)
even_odd()
# Out:
# enter a number: 45
# 45 is an odd number
# 45

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        print(f'{num2} is an even number')
        return(num2)
    else:
        print(f'{num2} is an odd number')
        return(num2)
even_odd()
# Out:
# enter a number: 14
# 14 is an even number
# 14

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        print(f'{num2} is an even number')
        return(num2+10)
    else:
        print(f'{num2} is an odd number')
        return(num2+20)
even_odd()
# Out:
# enter a number: 15
# 15 is an odd number
# 35

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        return(num2)
    else:
        return(num2)
output=even_odd()
print(output)
# Out:
# enter a number: 25
# 25

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        return(f'{num2} is an even number')
    else:
        return(f'{num2} is an odd number')
        
even_odd()
# Out:
# enter a number: 58
# '58 is an even number'

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        return(f'{num2} is an even number')
    else:
        return(f'{num2} is an odd number')
        
num2=even_odd()
print(num2)
# Out:
# enter a number: 58
# 58 is an even number

# %%
def even_odd():
    num2=eval(input('enter a number:'))
    if num2%2==0:
        val=10
        print(f'{num2} is an even number')
        return(num2+10)
    else:
        val=20
        print(f'{num2} is an odd number')
        return(num2+20)
num2=even_odd()
print(num2)
# Out:
# enter a number: 59
# 59 is an odd number
# 79

# %% [markdown]
# **function in function**

# %%
def greet1():
    print('hello goodmorning')
def greet2():
    print('hello goodnight')

greet1()
greet2()
# Out:
# hello goodmorning
# hello goodnight

# %%
def greet1():
    print('hello goodmorning')
def greet2():
    print('hello goodnight')
    greet1()

greet1()
greet2()
# Out:
# hello goodmorning
# hello goodnight
# hello goodmorning

# %%
def greet1():
    print('hello goodmorning')
    greet2()
def greet2():
    print('hello goodnight')
greet1()
# Out:
# hello goodmorning
# hello goodnight

# %%
def greet1():
    print('hello goodmorning')
    greet2()
def greet2():
    print('hello goodnight')
    greet1()
greet1()
# Out:
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# hello goodmorning
# hello goodnight
# ...

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)
add()
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)
    return(c)
c=add()
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    return(c+5)
c=add()
print(c)
# Out:
# 35

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)
    return(c+10)
c=add()
print(c)
# Out:
# 30
# 40

# %%
def greet3():
    print('i dont know what iam doing')
    greet3()
greet3()
# Out:
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# i dont know what iam doing
# ...

# %%
def add(n):
    if n==0:
        return(0)
    else:
        print(n)
        return(n+add(n-1))
output=add(5)
print('output is:',output)
# Out:
# 5
# 4
# 3
# 2
# 1
# output is: 15

# %%
# q1) Factorial recursion 5! = 5*4*3*2*1
# q2) calculator

# step-1: create 4 functions
# def add(a,b):
#     return(a+b)
#def mul
#def div
#def sub

#print('enter 1 for add 2 for sub and so on')



def main():
    option=eval(input('enter between 1 to 4'))
    if option==1:
        a=
        b=
